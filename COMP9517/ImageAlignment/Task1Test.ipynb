# %% [markdown]
# # Assignment 1 Task 1 Test
# + Some new test cases, including some large images

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import task1loop
import task1matrix

# %%
def compare_image(img1, img2):
    if len(img1.shape) > 2:
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
    if len(img2.shape) > 2:
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(16, 8))
    ax1 = plt.subplot(121)
    ax1.imshow(img1)
    ax1.set_xticks([])
    ax1.set_yticks([])
    ax2 = plt.subplot(122)
    ax2.imshow(img2)
    ax2.set_xticks([])
    ax2.set_yticks([])
    plt.show()

# %% [markdown]
# ## Test Case 1

# %%
raw_img = cv2.imread("test1.jpg")
print raw_img.shape
merged_img = task1loop.task1("test1.jpg", 0.50, 0.50, 30, 15, 1)
# Out:
# (1024, 397, 3)
# [5, 0, 0, 1]
# [14, 8, 2, 12]
# Running time : 2.636199

# %%
compare_image(raw_img, merged_img)

# %% [markdown]
# ## Test Case 2

# %%
raw_img = cv2.imread("test2.jpg")
print raw_img.shape
merged_img = task1loop.task1("test2.jpg", 0.50, 0.50, 40, 11, 1)
# Out:
# (1024, 397, 3)
# [10, 1, 6, 3]
# [10, 2, 0, 6]
# Running time : 1.42956

# %%
compare_image(raw_img, merged_img)

# %% [markdown]
# ## Test Case 3
# + This is a large image: (4646, 1800, 3)

# %%
raw_img = cv2.imread("test3.jpg")
merged_img = task1loop.task1("test3.jpg", 0.50, 0.50, 30, 10, 2)
# Out:
# [72, 0, 48, 8]
# [72, 56, 16, 72]
# Running time : 5.979341

# %%
compare_image(raw_img, merged_img)

# %% [markdown]
# ## Test Case 4

# %%
raw_img = cv2.imread("test4.jpg")

# %%
merged_img = task1loop.task1("test4.jpg", 0.40, 0.70, 45, 10, 2)
# Out:
# [72, 56, 64, 56]
# [72, 56, 8, 64]
# Running time : 13.067681

# %%
compare_image(raw_img, merged_img)

# %% [markdown]
# ## Test Case 5

# %%
raw_img = cv2.imread("test_sample1.jpg")
merged_img = task1loop.task1("test_sample1.jpg", 0.50, 0.60, 30, 13, 1)
# Out:
# [6, 12, 0, 10]
# [12, 12, 0, 9]
# Running time : 1.882581

# %%
compare_image(raw_img, merged_img)

# %% [markdown]
# ## For image which is extreme large (9782, 3780, 3), methods in Task 1 are computational expensive and not accurate
