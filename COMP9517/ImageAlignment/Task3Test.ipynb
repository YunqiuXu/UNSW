# %% [markdown]
# # Assignment 1 Task 3 Test
# ## 1. Preview the Image

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image, ImageEnhance
import task1loop
import task1matrix
import task2
import task3

# %%
def compare_image(img1, img2):
    if len(img1.shape) > 2:
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
    if len(img2.shape) > 2:
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(16, 8))
    ax1 = plt.subplot(121)
    ax1.imshow(img1)
    ax1.set_xticks([])
    ax1.set_yticks([])
    ax2 = plt.subplot(122)
    ax2.imshow(img2)
    ax2.set_xticks([])
    ax2.set_yticks([])
    plt.show()

# %%
raw_img = cv2.imread("test7.jpg")
merged_img = task1loop.task1("test7.jpg", 0.4, 0.5, 30, 12, 1)
# Out:
# [5, 8, 0, 6]
# [11, 7, 0, 4]
# Running time : 1.522269

# %%
compare_image(raw_img, merged_img)

# %%
cv2.imwrite('task3merge.jpg', merged_img)
# Out:
# True

# %% [markdown]
# ## 2. Remove the Border

# %%
cutted_img = task3.remove_border(merged_img, kernel_size = 5, canny_min = 50, canny_max = 150, int_upper = 5, int_lower = 15, int_left = 5, int_right = 10)
compare_image(merged_img, cutted_img)

# %% [markdown]
# ## 3. Histogram Equalization

# %%
he_img = task3.histEq(cutted_img)
hist_img = task3.get_histogram(he_img)
compare_image(he_img, hist_img)

# %% [markdown]
# ## 4. White Balance
# + Here we do not use white balance

# %% [markdown]
# ## 5. Contrast / Brightness / Satuaration / Sharpness

# %%
brightness_img = task3.brightness(he_img, 0.95)
compare_image(he_img, brightness_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f0b4cf014d1d> in <module>()
# ----> 1 brightness_img = task3.brightness(he_img, 0.95)
#       2 compare_image(he_img, brightness_img)
#
# NameError: name 'task3' is not defined

# %%
contrast_img = task3.contrast(brightness_img, 0.9)
compare_image(brightness_img, contrast_img)

# %%
color_img = task3.color(contrast_img, 0.9)
compare_image(contrast_img, color_img)

# %%
sharp_img = task2.sharpen(color_img, 1.5)
compare_image(color_img, sharp_img)

# %% [markdown]
# ## 6. Final Comparation

# %%
compare_image(merged_img, sharp_img)
